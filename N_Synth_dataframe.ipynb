# %%
import pandas as pd
import json

# %%
filepath ="audio\\N_synth\\examples.json"

df = pd.read_json(filepath)
df=df.T
# with open(filepath) as f:
#     data = json.load(f)
# print(data)

# %%
df
# Out:
#                                 instrument instrument_family  \
# guitar_acoustic_001-082-050             39                 3
# bass_synthetic_120-108-050             881                 0
# organ_electronic_120-050-127           979                 6
# guitar_electronic_021-026-025          346                 3
# organ_electronic_011-079-075           188                 6
# keyboard_electronic_089-044-100        877                 4
# bass_synthetic_016-080-127             241                 0
# keyboard_acoustic_010-084-127          599                 4
# keyboard_acoustic_011-053-127          690                 4
# keyboard_electronic_100-040-025        919                 4
# vocal_synthetic_012-086-100            202                10
# vocal_synthetic_007-064-025             95                10
# organ_electronic_002-068-100            13                 6
# keyboard_electronic_065-069-025        791                 4
# ...
